# %%
def get_hash(key):
    sum = 0
    for element in key:
        sum += ord(element)
    return(sum%100)

# %%
get_hash('a')
# Out:
# 97

# %%
class HashTable:
    def __init__(self):
        self.length = 100
        self.arr = [None for i in range(self.length)]

    def get_hash(self,key):
        hash = 0
        for element in key:
            hash += ord(element)
        return(hash%self.length)
    
    def __setitem__(self,key,value):
        index = self.get_hash(key)
        self.arr[index] = value

    def __delitem__(self,key):
        index = self.get_hash(key)
        self.arr[index] = None

    def __getitem__(self,key):
        index = self.get_hash(key)
        return self.arr[index]

# %%
t = HashTable()

# t.add_element('march 6','teotote')
# print(t.get_element('march 6'))
# t.remove_element('march 6')
# print(t.get_element('march 6'))
t['march 6'] = 'giganigga'
t['mhch 1'] = 'ArithmeticError'

# %%
t.arr
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'giganigga',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ArithmeticError',
#  None,
#  None]

# %%
del t['march 6']

# %%
t.arr
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'ArithmeticError',
#  None,
#  None]
